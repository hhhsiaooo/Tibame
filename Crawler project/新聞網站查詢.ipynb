# %%
# -*- coding: utf-8 -*-
import requests
from bs4 import BeautifulSoup
import re


new_list = []
url = 'https://money.udn.com/money/index'

## 1.填寫headers
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:88.0) Gecko/20100101 Firefox/88.0'}

response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')
#print(response.text)

## 2.抓取即時區域所有新聞title以及新聞內容連結link，並將每篇新聞的連結link append到new_list內
div_tag = soup.find('div', {'id':'tab1'})

soup2 = BeautifulSoup(str(div_tag), 'html.parser')
a_tags = soup2.find_all('a')


for i in a_tags:
    print('title: {}, link: {}'.format(i.text, 'https://money.udn.com'+i['href']))
    new_list.append('https://money.udn.com'+i['href'])
# Out:
# title: 23:12國台辦稱願援台疫苗 陸委會：統戰分化操作, link: https://money.udn.com/money/story/5604/5482532?from=edn_breaknewstab_index
# title: 23:12日本開始大規模施打疫苗 菅義偉視察感到安心, link: https://money.udn.com/money/story/5599/5482529?from=edn_breaknewstab_index
# title: 23:12北市議員林亮君同仁1確診2篩陽 特助吳崢自爆被載走了, link: https://money.udn.com/money/story/7307/5482502?from=edn_breaknewstab_index
# title: 23:06義大利纜車墜毀增至14死 唯一倖存幼童生命垂危, link: https://money.udn.com/money/story/5599/5482511?from=edn_breaknewstab_index
# title: 23:06WHA開幕 馬克宏指世衛組織應保持透明性, link: https://money.udn.com/money/story/5599/5482512?from=edn_breaknewstab_index
# title: 23:00白俄逼客機迫降逮人 歐盟考慮航道避開白俄領空, link: https://money.udn.com/money/story/5599/5482497?from=edn_breaknewstab_index
# title: 23:00企業經濟學家預測 美國今年GDP成長將創37年新高, link: https://money.udn.com/money/story/5599/5482498?from=edn_breaknewstab_index
# title: 22:54長賜輪卡蘇伊士運河 埃及求償金額降至154億元, link: https://money.udn.com/money/story/5599/5482469?from=edn_breaknewstab_index
# title: 22:54WHA台灣提案辯論  史瓦帝尼直指中國發言不實, link: https://money.udn.com/money/story/7307/5482472?from=edn_breaknewstab_index

# %%
from time import sleep
import os
from bs4 import BeautifulSoup
from urllib.request import urlretrieve

def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
    except OSError:
        print ('Error: Creating directory. ' +  directory)

        
def save_news(url):
    
    ## 3.填寫headers
    headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:88.0) Gecko/20100101 Firefox/88.0'}
    response = requests.get(url, headers=headers)
    sleep(1)
    
    soup = BeautifulSoup(response.text, 'html.parser')
    ## 4. 使用find_all去抓取每篇新聞的title(指定是哪個tag以及指定id)，將結果所產生之list放到new_title變數內
    new_title = soup.find_all('h2', {'id':'story_art_title'})

    save_path = './news/'+new_title[0].text.replace(':','')
    
    article_body = soup.find_all('div',{'id':'article_body'})
    print('new title: {}'.format(new_title[0].text))

    ## create folder
    createFolder(save_path)
    soup2 = BeautifulSoup(str(article_body[0]), 'html.parser')


    ## save article contens in folder
    with open(save_path+'/contents.txt', 'w', encoding='utf-8') as f:  
        ## 5. 抓取文章內p tags，並將新聞內文寫入contents.txt檔案內
        p_tags = soup2.find_all('p')
        print('new content: ')
        for i in p_tags:
            print(i.text)
            f.write(i.text)

    ## save image in article        
    
    ## 6. 抓取文章內所有img tags，並將圖片下載並存入對應新聞資料夾下
    img_tags = soup2.find_all('img')
    print('save image: ')
    for i in img_tags:
        print(i['src'])
        urlretrieve(i['src'], save_path+'/'+i['title']+'.jpg')
    print('==========\n\n')
    

for new_url in new_list:
    print(new_url)
    save_news(new_url)
# Out:
# https://money.udn.com/money/story/5604/5482532?from=edn_breaknewstab_index
# new title: 國台辦稱願援台疫苗 陸委會：統戰分化操作
# new content:
# 中國大陸國台辦今晚聲稱，陸方願迅速安排台灣民眾盡快使用其疫苗，也願考慮派防疫專家來台。陸委會則回應，陸方從未提供其疫苗資訊，只是明顯的統戰分化操作。
#
# 陸委會並表示，台灣向外取得疫苗受到何種阻撓，對岸心知肚明，眾人也已週知，多言無益。
#
# 中國大陸國台辦晚間以發言人朱鳳蓮「答記者問」名義聲稱，陸方「十分憂慮」台灣疫情，願迅速安排「廣大台灣民眾盡快有大陸疫苗可用」；若有需要，也願「積極考慮向台灣派出疫情防控專家，與台灣醫療衛生人士分享抗疫經驗，提供防疫諮詢」。
#
# 國台辦並宣稱，「民進黨當局要立即停止各種對大陸協助廣大台灣同胞抗疫進行的污蔑抹黑，採取切實行動去除人為障礙，讓廣大台灣同胞的生命健康、利益福祉盡早得到應有的保障」。
#
# 陸委會隨後針對國台辦說法發布新聞稿指出，陸方從未藉既有管道向台灣提供陸方疫苗的資訊，卻放話批評台灣阻撓陸製疫苗輸入。
#
# 陸委會表示，陸方這種每每藉台灣疫情升溫時，明顯進行分化統戰的操作，台灣社會非常明瞭，國際社會也都清楚認知。
# save image:
# ==========
#
#
# https://money.udn.com/money/story/5599/5482529?from=edn_breaknewstab_index
# new title: 日本開始大規模施打疫苗 菅義偉視察感到安心
# new content:
# 日本政府在東京與大阪各設一處大規模疫苗接種中心，今天開始施打。日本首相菅義偉下午視察東京會場，看到現場秩序井然感到很放心。日本目前最大的問題是缺乏打針的人手。
#
# 日本政府為加速境內2019冠狀病毒疾病（COVID-19）疫苗施打進度，在東京都及大阪府各開設一處大規模疫苗接種中心，由自衛隊負責相關工作。
#
# 東京及大阪會場今天上午8時同步啟動施打作業，首批施打對象是部分居住在東京23區及大阪市65歲以上長者，使用21日剛獲日本政府批准的美國莫德納（Moderna）疫苗。
#
# 菅義偉今天下午在防衛大臣岸信夫及副防衛大臣中山泰秀等官員的陪同下視察東京施打疫苗的會場。視察後他對媒體表示，就如自衛隊的作法，很有組織、很有秩序地施打疫苗，看了感到很安心。
#
# 日本政府目前確保有足夠的疫苗，但全國各級政府（都道府縣市町村等）向中央政府反映打針的人手不足。菅義偉對此表示，正在協調數萬名包括護理緊急醫療技術員等在內的人員。
#
# 因為防疫不力，加上施打疫苗速度落後於其他歐美國家，去年9月上台的菅內閣目前支持率低迷，日媒紛紛報導，施打疫苗的進度攸關菅義偉能否拉抬內閣支持率。
#
#
#
#
# 林亮君提到，這名同仁於5月17日出現不適症狀，5月18日前往快篩站檢測，當日快篩結果為陰性，今天才接獲PCR陽性通知。目前同仁健康狀況穩定，衛生局已安排近日前往檢疫所隔離。
#
#
#
# 林亮君說，她心情雖然有些波動，但會全力配合政府的一切防疫指引與自肅，同時線上服務也不會中斷，各位市民有任何狀況一樣歡迎和她聯絡，會全力繼續為大家服務。「期待台灣團結早日度過疫情！」無黨籍台北市議員林亮君。 圖／取自林亮君粉專facebook林亮君特助吳崢也在臉書表示，「快篩陽性，突然就被送上車載走了，好不真實！」「等待進一步ＰＣＲ檢測，希望是偽陽。」圖／引用自吳崢臉書facebook
# save image:
# https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/05/24/realtime/12349516.png&x=0&y=0&sw=0&sh=0&sl=W&fw=1050&exp=3600&exp=3600
# https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/05/24/realtime/12349517.png&x=0&y=0&sw=0&sh=0&sl=W&fw=1050&exp=3600&exp=3600
# ==========
#
#
# https://money.udn.com/money/story/5599/5482511?from=edn_breaknewstab_index
# new title: 義大利纜車墜毀增至14死 唯一倖存幼童生命垂危
# new content:
# 義大利山區昨天發生可怕纜車墜毀事故，造成5名以色列人在內等14人死亡，並有一名幼童生命垂危，調查人員今天正在調查這起事故原因。
#
# 義大利西北部比第蒙省（Piedmont）地區莫塔羅納山（Mottarone）山頂昨天發生纜車墜毀事故，唯一倖存者是一名5歲男童，仍在醫院治療，醫院高層表示，未來兩天將是存活關鍵。
#
# 根據最初報導，這輛纜車在一條電纜斷裂後墜落地面。與此同時，一名緊急服務人員表示，纜車上安全煞車失靈。
#
# 義大利運輸部長喬凡尼尼（Enrico Giovannini）已抵達纜車起始處斯特里薩鎮（Stresa），會見地方及地區當局。
#
# 檢方已針對這起可能的過失殺人罪展開偵訊。與此同時，政府委託的技術專家調查也正在進行。
# save image:
# ==========
#
#
# https://money.udn.com/money/story/5599/5482512?from=edn_breaknewstab_index
# new title: WHA開幕 馬克宏指世衛組織應保持透明性
# new content:
# （中央社記者唐佩君、戴雅真布魯塞爾/倫敦24日專電）世界衛生大會今天開議，法國總統馬克宏及德國總理梅克爾應邀發言，馬克宏提到世界衛生組織應保持透明性、梅克爾則呼籲各國支持締結疫情大流行全球條約。
#
# 第74屆世界衛生大會（WHA）自5月24日至6月1日以視訊方式舉行，今天大會開幕首先邀請馬克宏（Emmanuel Macron）、梅克爾（Angela Merkel）等各國領袖演講。
#
# 馬克宏說，全球從這場2019冠狀病毒疾病（COVID-19）疫情危機中學到的教訓是大家都是共同生命體，沒有一個國家能獨善其身，因此不管在區域或國際層面一定要團結合作。
#
# 他說，世界衛生組織（WHO）應成為全球衛生工作的指導者，在危機時期保持穩定以靈活應對緊急情況，而且不應有任何政治壓力，必須完全透明，法國支持強化WHO發揮規範性作用，改善WHO的籌資，使其更具永續性及可預測性，及減少對幾個大捐助者的依賴。
#
# 這份調查結果是根據49名預測專家本月稍早提供的回覆，內容描繪出的美國經濟前景，比3月公布的前一份調查結果遠更樂觀；當時經濟學家總體預測，美國今年經濟成長率將僅4.8%。
#
# 美聯社報導，美國經濟先前經過2019冠狀病毒疾病（COVID-19）疫情沉重打擊，陷入1930年代大蕭條以來最嚴重衰退；其後在復甦過程中，持續表現驚人的強度和復原能力，最主要拜政府提供大量援助之賜。
#
# 由於經濟衰退造成數千萬人失業，美國國會去年通過4兆美元援助措施。美國新任總統拜登（Joe Biden）今年3月又推動今年內1兆9000億美元額外援助方案，其中包括發給大部分國民每人1400美元現金。
#
# 鑒於美國新增染疫人數減少，消費者支出增加，更多企業也恢復營業和聘雇人員，經濟學家持續上修美國經濟成長預測值。
#
# NABE的專家小組預測，現行4至6月的一季，依國內生產毛額（GDP）計算的美國年化經濟成長率為8.5%，較3月時預測值5.2%大幅提升。
#
# 美國政府先前公布，今年1至3月的一季，年化經濟成長率估計為6.4%。27日將發布的報告很可能會將數據上修。
#
# 隨著美國經濟復甦增強，外界越來越擔憂通貨膨脹壓力持續升高；美國4月消費者物價已出現10年來最大漲幅。
#
# 回覆NABE調查的專家預測，今年美國通貨膨脹率為2.8%，相較去年僅1.2%；明年通膨率預測則為2.3%。
#
# 儘管如此，NABE調查委員會主席韋德（Holly Wade）指出，預測的專家認為，若出現任何通膨升溫情況也將短暫。「通膨預期心理比3月調查時大幅升高，但專家小組成員預期，今年下半年通膨壓力將緩和。」
# save image:
# ==========
#
#
# https://money.udn.com/money/story/5599/5482469?from=edn_breaknewstab_index
# new title: 長賜輪卡蘇伊士運河 埃及求償金額降至154億元
# new content:
# 長榮海運長賜輪3月堵住蘇伊士運河，造成通行停擺，運河當局向日本船東正榮汽船求償。運河管理局主席昨天晚間表示，求償金額已降至5億5000萬美元（約新台幣154億元）。
#
# 法新社報導，埃及當局4月扣留排水量20萬噸的長賜輪（MV Ever Given），並在當地法院提出告訴，向日本船東「正榮汽船」求償9億1600萬美元（約新台幣256億元）。
#
# 不過，蘇伊士運河管理局（SCA）主席雷比（OsamaRabie ）昨天晚間接受電視脫口秀節目主持人阿迪布（Amr Adib）訪問時表示，求償金額已經降至5億5000萬美元。
#
# 雷比：「船東預估船上載運貨物的成本約7億7500萬美元，我們尊重這點，把求償金額降至5億5000萬美元。」
#
# 長賜輪（Ever Given）是全球最大貨櫃輪之一，3月23日遭遇沙塵暴，打斜堵住河道，阻礙運河雙向交通，干擾全球貿易。運河當局動員了埃及人力和國際救援專家，花了6天的時間，才將擱淺的長賜輪移離河道。
#
# 蘇伊士運河連接紅海和地中海，全球貿易逾10%仰賴這條連結亞洲和歐洲的水道。
#
# 根據蘇伊士運河管理局，運河封閉期間，埃及每天損失1200萬至1500萬美元不等的營收。
#
# 蘇伊士運河管理局所處的伊斯梅利亞（Ismailia）法院今天裁決，運河管理局向正榮汽船求償案將移至專門法院審理，訂5月29開庭。
# save image:
# ==========
#
#
# https://money.udn.com/money/story/7307/5482472?from=edn_breaknewstab_index
